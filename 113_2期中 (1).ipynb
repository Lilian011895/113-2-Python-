# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import re

def scrape_professors_expertise(base_url="https://csie.asia.edu.tw/zh_tw/associate_professors_2", max_pages=5):
    all_professors = []

    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

    for page in range(1, max_pages + 1):
        if page == 1:
            current_url = base_url
        else:
            current_url = f"{base_url}?page_no={page}"

        try:
            req = Request(current_url, headers=headers)
            html = urlopen(req)
            soup = BeautifulSoup(html, 'html.parser')

            text = soup.get_text()

            pattern = r'姓名[\s\:：]+([\w\(\)\-\,\. ]+)\s*\n+\s*職稱[\s\:：]+([^\n]+)\s*\n+[\s\S]*?研究領域[\s\:：]+([\s\S]*?)(?=\s*Office hour|網站|分機)'
            matches = re.findall(pattern, text)

            if not matches and page > 1:
                break

            for match in matches:
                name, title, expertise = match
                name = name.strip()
                expertise = expertise.strip().replace('\n', ' ')

                expertise = expertise.replace(', ', '、').replace('，', '、').replace(' ,', '、')
                expertise = expertise.replace(',、', '、')

                all_professors.append({
                    '姓名': name,
                    '專長': expertise
                })

                print(f"教授: {name}, 專長: {expertise[:50]}...")

        except Exception as e:
            break

    special_cases = [
        {"姓名": "Tadao Murata", "專長": "分散式通訊軟體、網路協議、邏輯與規則基礎AI系統、製造系統、平行計算系統和具有模糊延遲的系統的Petri網應用"},
        {"姓名": "曾憲章(Zeng Xianzhang)", "專長": "計算機科學"},
        {"姓名": "李錦輝(Chin-Hui Lee)", "專長": "語音訊號處理、機器學習"},
        {"姓名": "黃光彩", "專長": "電機工程"},
        {"姓名": "林一平(Jason Yi-Bing Lin)", "專長": "個人通信網路、行動計算、系統模擬"},
        {"姓名": "張嘉淵(Zhang Jiayuan)", "專長": "雲端運算、大數據分析、演算法、社群媒體、人工智慧物聯網、人本創新應用"},
        {"姓名": "許健(Gene Sheu)", "專長": "電子電路、微電子、產品研發、積體電路"},
        {"姓名": "梁文隆(Wen-Lung Liang)", "專長": "物聯網技術、嵌入式系統、智慧家庭"},
        {"姓名": "林詠章(Lin Yongzhang)", "專長": "資訊安全、區塊鏈應用、精準健康、智慧醫療、工控安全"}
    ]

    for case in special_cases:
        all_professors.append(case)
        print(f"教授: {case['姓名']}, 專長: {case['專長'][:50]}...")

    return all_professors

def save_simple_output(professors_data, filename="professors_expertise_simple.txt"):
    with open(filename, 'w', encoding='utf-8') as txtfile:
        for professor in professors_data:
            txtfile.write(f"教授: {professor['姓名']}, 專長: {professor['專長']}\n")

    print(f"資料已保存至 {filename}")

def main():
    associate_professors = scrape_professors_expertise("https://csie.asia.edu.tw/zh_tw/associate_professors_2")

    assistant_professors = scrape_professors_expertise("https://csie.asia.edu.tw/zh_tw/assistant_professors_2")

    lecturers = scrape_professors_expertise("https://csie.asia.edu.tw/zh_tw/senior_lecturer")

    professors = scrape_professors_expertise("https://csie.asia.edu.tw/zh_tw/all_professors_1")

    all_professors = associate_professors + assistant_professors + lecturers + professors

    unique_professors = []
    seen_names = set()
    for professor in all_professors:
        if professor['姓名'] not in seen_names:
            unique_professors.append(professor)
            seen_names.add(professor['姓名'])

    save_simple_output(unique_professors)

if __name__ == "__main__":
    main()
# Out:
# 教授: 張文鐘 (Wen-Thong Chang), 專長: 物連網系統、視訊串流、通訊系統、影像處理...
# 教授: 許聞廉(Wen-Lian Hsu), 專長: 演算法分析、生物資訊、計算語言、自然語言理解、智慧型對話系統...
# 教授: 陳良弼(Arbee L.P. Chen), 專長: 巨量資料分析、資料庫偏愛查詢、行動資訊系統...
# 教授: 黃明祥(Min-Shiang Hwang), 專長: 資訊與網路安全、密碼與藏密學、區塊鏈技術、智慧運算與行動通訊、管理資訊系統...
# 教授: 許慶賢(Ching-Hsien Hsu), 專長: 雲端計算、人工智慧與應用、高性能計算、大數據與串流運算、平行與分散式系統、智慧醫療...
# 教授: 李文熙(Wen-Hsi Lee), 專長: 有機薄膜電晶體、半導體薄膜製程、薄膜太陽能電池、電子陶瓷、射頻陶瓷元件、系統構裝...
# 教授: 陳錫明(Shyi-Ming Chen), 專長: 模糊系統、智慧型系統、模糊決策、智慧型計算、知識庫系統、機器學習、資料探勘、大數據分析、遺傳演算法、...
# 教授: 洪西進(Shi-Jinn Horng), 專長: 深度學習與大數據、生物辨識技術、資訊安全、雲端和容錯計算、多媒體應用、醫療應用...
# 教授: 詹景裕(Gene-Eu Jan), 專長: 電腦結構、平行處理、交換網路、超大型積體電路設計...
# 教授: 蔡秀芬(Shiow-Fon Tsay), 專長: 凝態物理理論、計算物理、工程數學...
# 教授: 蕭進松(Chin-Sung Hsiao), 專長: 光電半導體、奈米電漿元件、積體光學、電磁計算...
# 教授: 陳興忠(Hsing-Chung Chen), 專長: 資通訊安全、人工智慧、應用密碼學、智慧物聯網、 區塊鏈技術應用與安全、量子安全供應信賴鏈...
# 教授: Brij Bhooshan Gupta, 專長: 資訊安全、計算機網路、軟體工程...
# 教授: 施能義(Neng-Yih Shih), 專長: 計算處理與應用、無線感測與轉換、智慧控制系統、定位與追縱...
# 教授: 林俊淵(Chun-Yuan Lin), 專長: 平行與分散式處理 (MPI、OpenMP、CUDA)、生物資訊(基因體學、蛋白質體學、系統生物學、S...
# 教授: 蔡志仁(Zhi-Ren Tsai), 專長: 適應控制、電腦視覺、機器人學、電力電子...
# 教授: 陳兆南(Chao-Nan Chen), 專長: 影像顯示科技、多媒體及3D遊戲設計、VLSI技術...
# 教授: 陳瑞奇(Jui-Chi Chen), 專長: 資通工程(健康照護)、資料探勘與分析、無線網路資源管理、電腦網路...
# 教授: 朱學亭(Hsueh-Ting Chu), 專長: 生物資訊、數位學習、圖型識別、類神經網路、人工智慧...
# 教授: 王經篤(Jing-Doo Wang), 專長: 雲端計算 、文件資訊擷取 、網路資訊擷取 、生物資訊...
# 教授: 葉榮輝(Rong-Hwei Yeh), 專長: 太陽能電池、發光二極體、半導體雷射、非晶矽材料及元件...
# 教授: 柯賢儒 (Hsien-Ju Ko), 專長: 自動控制、訊號處理、電腦網路...
# 教授: 蔡至偉(Jr Wei, Tsai), 專長: 機器學習與深度學習應用、訊號處理與演算法開發、圖資料應用與數據挖掘...
# 教授: 楊偉儒 (Wei-Zu Yang), 專長: 個人通訊服務、網際網路電話、網路效能分析、高速網路、類神經網路...
# 教授: THI-VAN NGUYEN, 專長: 機器學習、深度學習、電腦視覺、影像處理、生物辨識技術、資料探勘...
# 教授: DINH-TRUNG VU, 專長: 生物辨識技術、電腦視覺、影像處理、深度學習...
# 教授: 涂崇一(Chung-Yi Tu), 專長: 六軸機械手臂軟體設計與應用、人工智慧、影像辨識、數據分析...
# 教授: 吳函諺(Han-Yan Wu), 專長: 資訊隱藏(可逆與不可逆式)、數位浮水印、影像處理...
# 教授: PANDI DIVYA PORKAIPANDI, 專長: 半導體裝置設計開發、半導體功率元件...
# 教授: 關國裕(Kuo-Yu Kuan), 專長: 邏輯設計、程式設計...
# 教授: Tadao Murata, 專長: Applications of Petri nets to problems related to ...
# 教授: 李正吉 (Li Zhengji), 專長: 行動通訊、資訊安全、密碼學、資訊網路與網路安全                姓名 :  徐中行 (...
# 教授: 陳義吉(Chen Yiji), 專長: 自動化製鞋機器設計開發、非破壞性檢測設備設計開發(涉獵領域:AOI 檢測、渦電流探傷)、自動化設備開...
# 教授: Tadao Murata, 專長: 分散式通訊軟體、網路協議、邏輯與規則基礎AI系統、製造系統、平行計算系統和具有模糊延遲的系統的Pet...
# 教授: 曾憲章(Zeng Xianzhang), 專長: 計算機科學...
# 教授: 李錦輝(Chin-Hui Lee), 專長: 語音訊號處理、機器學習...
# 教授: 黃光彩, 專長: 電機工程...
# 教授: 林一平(Jason Yi-Bing Lin), 專長: 個人通信網路、行動計算、系統模擬...
# 教授: 張嘉淵(Zhang Jiayuan), 專長: 雲端運算、大數據分析、演算法、社群媒體、人工智慧物聯網、人本創新應用...
# 教授: 許健(Gene Sheu), 專長: 電子電路、微電子、產品研發、積體電路...
# 教授: 梁文隆(Wen-Lung Liang), 專長: 物聯網技術、嵌入式系統、智慧家庭...
# 教授: 林詠章(Lin Yongzhang), 專長: 資訊安全、區塊鏈應用、精準健康、智慧醫療、工控安全...
# 教授: Tadao Murata, 專長: 分散式通訊軟體、網路協議、邏輯與規則基礎AI系統、製造系統、平行計算系統和具有模糊延遲的系統的Pet...
# 教授: 曾憲章(Zeng Xianzhang), 專長: 計算機科學...
# 教授: 李錦輝(Chin-Hui Lee), 專長: 語音訊號處理、機器學習...
# 教授: 黃光彩, 專長: 電機工程...
# 教授: 林一平(Jason Yi-Bing Lin), 專長: 個人通信網路、行動計算、系統模擬...
# 教授: 張嘉淵(Zhang Jiayuan), 專長: 雲端運算、大數據分析、演算法、社群媒體、人工智慧物聯網、人本創新應用...
# 教授: 許健(Gene Sheu), 專長: 電子電路、微電子、產品研發、積體電路...
# 教授: 梁文隆(Wen-Lung Liang), 專長: 物聯網技術、嵌入式系統、智慧家庭...
# 教授: 林詠章(Lin Yongzhang), 專長: 資訊安全、區塊鏈應用、精準健康、智慧醫療、工控安全...
# 教授: Tadao Murata, 專長: 分散式通訊軟體、網路協議、邏輯與規則基礎AI系統、製造系統、平行計算系統和具有模糊延遲的系統的Pet...
# 教授: 曾憲章(Zeng Xianzhang), 專長: 計算機科學...
# 教授: 李錦輝(Chin-Hui Lee), 專長: 語音訊號處理、機器學習...
# 教授: 黃光彩, 專長: 電機工程...
# 教授: 林一平(Jason Yi-Bing Lin), 專長: 個人通信網路、行動計算、系統模擬...
# 教授: 張嘉淵(Zhang Jiayuan), 專長: 雲端運算、大數據分析、演算法、社群媒體、人工智慧物聯網、人本創新應用...
# 教授: 許健(Gene Sheu), 專長: 電子電路、微電子、產品研發、積體電路...
# 教授: 梁文隆(Wen-Lung Liang), 專長: 物聯網技術、嵌入式系統、智慧家庭...
# 教授: 林詠章(Lin Yongzhang), 專長: 資訊安全、區塊鏈應用、精準健康、智慧醫療、工控安全...
# 教授: Tadao Murata, 專長: 分散式通訊軟體、網路協議、邏輯與規則基礎AI系統、製造系統、平行計算系統和具有模糊延遲的系統的Pet...
# 教授: 曾憲章(Zeng Xianzhang), 專長: 計算機科學...
# 教授: 李錦輝(Chin-Hui Lee), 專長: 語音訊號處理、機器學習...
# 教授: 黃光彩, 專長: 電機工程...
# 教授: 林一平(Jason Yi-Bing Lin), 專長: 個人通信網路、行動計算、系統模擬...
# 教授: 張嘉淵(Zhang Jiayuan), 專長: 雲端運算、大數據分析、演算法、社群媒體、人工智慧物聯網、人本創新應用...
# 教授: 許健(Gene Sheu), 專長: 電子電路、微電子、產品研發、積體電路...
# 教授: 梁文隆(Wen-Lung Liang), 專長: 物聯網技術、嵌入式系統、智慧家庭...
# 教授: 林詠章(Lin Yongzhang), 專長: 資訊安全、區塊鏈應用、精準健康、智慧醫療、工控安全...
# 資料已保存至 professors_expertise_simple.txt
